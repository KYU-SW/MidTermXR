# %% [markdown]
# # 중간고사 (메타버스 프로그래밍) 라이브 코딩 테스트
#
# - 규칙 1. ChatGPT, Gemini, Claude, Perplexity 등 대화형 인공지능을 활용한 문제 풀이시 F 학점
# - 규칙 1-1. Visual Studio Code 의 Generate 기능 해제 할 것. (시험 중 확인 예정)
# - 규칙 2. 교수자에게 정답 유무 질문 가능. 단, 어느 것이 틀렸는지에 대해서는 언급하지 않음
# - 규칙 2-1. 구두로 정답을 언급하였지만, 시험 이후 상세 체험을 통해 감점이 발생할 수 있음
# - 규칙 3. 해당 파일 이외의 다른 문서 파일에 코드를 작성한 것은 채점하지 않음
# - 규칙 4. 인터넷 검색 가능, 기존 소스코드 참고 가능, PPT 참고 가능, 그러나 친구에게 문의하는 것, 카카오톡, 인스타 DM 등 메신저 안 됨
# - 규칙 5. 최종 파일은 LXP 에 업로드 할 것. LXP 미 업로드시  0 점 처리.  코드 저장 여부 확인할 것.
# - 규칙 6. 시험 중 타인의 화면을 보거나 자신의 화면을 타인에게 보여주는 행위, 좌석 이동을 금지함. 적발 시 0점 처리함.
# - 규칙 7. 시험 시작 이후 10분 뒤, PC 오류에 대한 조치 불가. 미리 확인할 것.
# - 규칙 8. 시험 이후, 교수자가 요구할 경우, 본인이 작성한 코드에 대해서 구두로 설명할 수 있어야 함.
# - 규칙 9. 주석 처리된 미완성 코드나 복수의 시도본이 남아있더라도, 최종적으로 실행되는 결과를 기준으로 채점함.  한 문제에 단일한 실행 코드만을 남겨놓을 것.
# - 규칙 10. 모든 문제는 10점이며, 부분 점수를 부여함. 총점 100점.
# - 규칙 11. 시험 중 이어폰, 헤드셋 착용 금지
# - 규칙 12. 시험과 무관한 웹 사이트 서핑 금지

# %% [markdown]
# ![그림2.png](data:image/png;base64,...)

# %% [markdown]
# ## 1. 본인의 학과, 학번과 이름을 출력하시오
#
# 1을 입력하면, 본인의 학과가 출력되고
#
# 2를 입력하면, 본인의 학번이 출력되고
#
# 3을 입력하면, 본인의 이름이 출력되고
#
# 4를 입력하면, 본인의 학과, 학번, 이름이 모두 출력되도록 프로그램을 작성하시오.
#
# ### 입력 예제
#
# 2
#
# ### 출력 결과물
# ```
# 2026XXXX
# ```
#
#
# ### 입력 예제
#
# 4
#
# ### 출력 결과물
# ```
# 국방XR학부 2026XXXX 이름
# ```

# %%
#########################################################
# 1번 문제 코드 작성하기
########################################################

n = int(input(' 숫자를 입력하세요: '))

if n == 1:
    print('국방XR학부')
else:
    if n == 2:
        print('26521003')
    else:
        if n == 3:
            print('곽민수')
        else:
            if n == 4:
                print('국방XR학부 26521003 곽민수')
# Out:
# 국방XR학부 26521003 곽민수

# %% [markdown]
# ![그림2.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. 계산기 만들기
#
# 숫자 그리고 연산자 ( +, -, *, /, %) 그리고 숫자가 차례대로 입력되었을 때, 결과 값을 출력하시오.
# 단, / 또는 % 연산에서 두 번째 숫자가 0 인 경우 Error 를 출력하시오.
#
# ### **입력**
# 숫자, 연산자, 숫자 입력
#
# ### **출력**
# 계산 결과 값
# 단, 0으로 나누는 경우 `Error` 출력
#
# ### **예시**
#
# ```
# 입력: 5 + 6
# 출력: 11
#
# 입력: 18 / 6
# 출력: 3
#
# 입력: 10 % 0
# 출력: Error
# ```

# %%
#########################################################
# 2번 문제 코드 작성하기
########################################################
data = input().split()

num1 = int(data[0])
operator = data[1]
num2 = int(data[2])

if operator == '+':
    print(num1 + num2)
elif operator == '-':
    print(num1 - num2)
elif operator == '*':
    print(num1 * num2)
elif operator == '/':
    if num2 != 0:
        print(num1 / num2)
    else:
        print("0으로 나눌수 없습니다.")

# %% [markdown]
# ![그림2.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. 조건문과 반복문을 이용해 수 정렬하기
#
# 조건 문을 이용해서, n개의 수를 오름차순으로 차례대로 정렬하여 출력하고 **바로 이어서 내림차순으로 정렬**한 값도 같이 출력하기
#
# n 개의 수를 랜덤 함수를 통해서 얻어내고, 이를 정렬한 값을 출력한다.
#
# **(주의)  리스트 함수 중 sort()를  이용한 풀이는 정답으로 인정하지 않음**
#
# ### **힌트**
# - `random.randint()`를 이용하면 랜덤한 정수를 만들 수 있음
# - 먼저 반복문을 이용해 n개의 수를 생성해서 저장할 것
# - `sort()`를 쓰지 말고, 두 수를 서로 비교해서 자리를 바꾸는 방식으로 정렬할 것
# - 오름차순 정렬이 끝난 뒤, 뒤에서부터 출력하면 내림차순도 만들 수 있음
#
# ### **입력**
# 첫 줄에 n 개의 값을 입력
#
# ### **출력**
# 오름 차순으로 정렬된 값 출력 이후 바로 이어서 내림 차순으로 정렬된 값 출력하기
#
# ### 입력 예제
# ```
# 5
# ```
# ### 출력 예제
# ```
# 12  17  18  21   28   28  21  18  17  12
# ```

# %%
#########################################################
# 3번 문제 코드 작성하기
########################################################

n = int(input())
data = list(map(int, input().split()))

for i in range(len(data)):
    for j in range(len(data) - 1 - i):
        if data[j] > data[j+1]:

            data[j], data[j+1] = data[j+1], data[j]

for x in data:
    print(x, end=' ')

for i in range(len(data) - 1, -1, -1):
    print(data[i], end=' ')
# Out:
# 12 17 18 21 28 28 21 18 17 12

# %% [markdown]
# ![그림2.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. 반복문 응용하기
#
# 예제를 보고 규칙을 유추한 뒤에, 별을 이용하여 모래시계 모양을 출력하세요.
#
#
# ### **입력**
# 첫째 줄에 N(1 ≤ N ≤ 100)이 주어진다.
#
# ### **출력**
# 첫째 줄부터 2×N-1번째 줄까지 차례대로 별을 출력한다.
#
# ### 입력 예제
# ```
# 5
# ```
# ### 출력 예제
# ```
# *********
#  *******
#   *****
#    ***
#     *
#    ***
#   *****
#  *******
# *********
# ```

# %%
#########################################################
# 4번 문제 코드 작성하기
########################################################

# import sys
# input = sys.stdin.readline
n = int(input().strip())
i = 0
for x in range(n*2-1):
    print(' ' * i + '*' * (n*2-1 - 2 * i))
    if x < n-1:
        i += 1
    else:
        i -= 1
# Out:
# *********
#  *******
#   *****
#    ***
#     *
#    ***
#   *****
#  *******
# *********

# %% [markdown]
# ![그림2.png](data:image/png;base64,...)

# %% [markdown]
# ## 5. 숫자의 합
#
# N개의 숫자가 공백 없이 쓰여있다. 이 숫자들 중 홀수만 모두 합해서 출력하는 프로그램을 작성하시오.
#
# ### **입력**
# 첫째 줄에 숫자의 개수 N (1 ≤ N ≤ 100)이 주어진다. 둘째 줄에 숫자 N개가 공백없이 주어진다.
#
# ### **출력**
# 입력으로 주어진 숫자 N개의 합을 출력한다.
#
# ### 입력 예제 1
# ```
# 5
# 54321
# ```
# ### 출력 예제 1
# ```
# 9
# ```
#
# ### 입력 예제 2
# ```
# 11
# 10987654321
# ```
# ### 출력 예제 2
# ```
# 26
# ```

# %%
#########################################################
# 5번 문제 코드 작성하기
########################################################
sum_1 = 0

n = int(input("n : "))

for i in range(1, n + 1):
     if i % 2 == 0 :
         sum_1 += i
print(sum_1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       4 sum_1 = 0
#       6 n = int(input("n : "))
# ----> 8 for i in range(1, n + 1):
#       9      if i % 2 == 0 :
#      10          sum_1 += i
#
# KeyboardInterrupt:

# %% [markdown]
# ![그림2.png](data:image/png;base64,...)

# %% [markdown]
# ## 6. Dictionary 를 이용하여 문제 풀것.
#
# 한 도서관에서는 학생들의 열람실 좌석 상태를 기록하고 있다.
# 각 학생은 현재 다음 3가지 상태 중 하나를 가질 수 있다.
#
# - `study` : 현재 열람실에서 공부 중
# - `break` : 잠시 자리를 비움
# - `exit` : 열람실을 완전히 나감
#
# 로그가 순서대로 주어질 때, 각 학생의 **마지막 상태**를 기준으로
# 현재 `study`, `break`, `exit` 상태인 학생들을 구하고, 각 상태별 인원 수도 함께 출력하는 프로그램을 작성하시오.
#
# ### **입력**
# 첫째 줄에 로그의 개수 `n`이 주어진다.
# 다음 `n`개의 줄에는 학생의 이름과 상태가 공백으로 구분되어 주어진다.
#
# 상태는 `study`, `break`, `exit` 중 하나이다.
#
# 학생의 이름은 알파벳 대소문자로 이루어진 10글자 이하의 문자열이며, 동명이인은 없다
#
# ### **출력**
#
# 첫째 줄에 `study` 상태인 학생 수를 출력한다.
# 둘째 줄부터는 `study` 상태인 학생의 이름을 사전 순으로 한 줄에 한 명씩 출력한다.
#
# 그 다음 줄에 `break` 상태인 학생 수를 출력한다.
# 이후 `break` 상태인 학생의 이름을 사전 순으로 한 줄에 한 명씩 출력한다.
#
# 그 다음 줄에 `exit` 상태인 학생 수를 출력한다.
# 이후 `exit` 상태인 학생의 이름을 사전 순으로 한 줄에 한 명씩 출력한다.
#
# 각 상태에 해당하는 학생이 없는 경우에는 인원 수만 `0`으로 출력한다.
#
#
# ### 입력 예제 1
# ```
# 7
# Mina study
# Joon study
# Mina break
# Sora study
# Joon exit
# Mina study
# Hana exit
# ```
# ### 출력 예제 1
# ```
# Study: 2
# Mina
# Sora
# Break: 0
# Exit: 2
# Hana
# Joon
# ```

# %%
#########################################################
# 6번 문제 코드 작성하기
########################################################

# import sys
# input = sys.stdin.readline
 
n = int(input())
dic = {}
 
for _ in range(n):
    name, record = input().split()
    if record == 'study':
        dic[name] = True
    elif record == 'break':
        del dic[name]
    elif record == 'exit':
        dic[name] = False
 
for name in sorted(dic.keys(), reverse=True):
    print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 17
#      15     elif record == 'break':
#      16         del dic[name]
# ---> 17     elif recod == 'exit':
#      18         dic[name] = False
#      20 for name in sorted(dic.keys(), reverse=True):
#
# NameError: name 'recod' is not defined

# %% [markdown]
# ![그림2.png](data:image/png;base64,...)

# %% [markdown]
# ## 7. 10진수 진법 변환
#
# 10진수가 주어졌을 때, 이를 2진수, 8진수, 16진수로 변환하여 출력하는 프로그램을 작성하시오.
#
# 단, `bin()`, `oct()`, `hex()` 함수는 사용할 수 없다.
#
# 부분점수
#  - 2진수 성공  (6점)
#  - 8진수 성공  (2점)
#  - 16진수 성공 (2점)
#
# ### **입력**
# 첫째 줄에 10진수 정수 N이 주어진다.
#
# ### **출력**
# 첫째 줄에 N의 2진수를 출력한다.
# 둘째 줄에 N의 8진수를 출력한다.
# 셋째 줄에 N의 16진수를 출력한다.
# 단, 16진수의 알파벳은 대문자 `A~F`로 출력한다.
#
# ### 입력 예제 1
# ```
# 10
# ```
# ### 출력 예제 1
# ```
# 2진수 : 1010
# 8진수 : 12
# 16진수: A
# ```

# %%
#########################################################
# 7번 문제 코드 작성하기
########################################################

value = 10


b = format(value, 'b')
o = format(value, 'o')
h = format(value, 'x')

print(b)
print(o)
print(h)

# %% [markdown]
# ![그림2.png](data:image/png;base64,...)

# %% [markdown]
# ## 8. 구구단 while 문을 이용해서 작성하시오
#
# while 문을 이용하여 구구단을 출력하는 프로그램을 작성하시오.
#
# 단, 시작 곱셈 수와 끝 곱셈 수도 함께 입력받아 해당 범위만 출력하시오.
#
# (for문을 이용하면 틀림)
#
# ### **입력**
# 첫째 줄에 구구단의 단계 N이 주어진다.
# 둘째 줄에 시작 숫자 A와 끝 숫자 B가 공백으로 주어진다.
#
# ### **출력**
# N × A 부터 N × B 까지 차례대로 출력한다.
#
# ### 입력 예제 1
# ```
# 2
# 3 7
# ```
# ### 출력 예제 1
# ```
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# ```

# %%
#########################################################
# 8번 문제 코드 작성하기
########################################################


dan = int(input("출력할 구구단 단수를 입력하세요: "))
start = int(input("시작 곱셈수를 입력하세요: "))
end = int(input("끝 곱셈수를 입력하세요: "))

print(f"--- {dan}단 {start}부터 {end}까지 ---")


current = start
while current <= end:

    result = dan * current
    print(f"{dan} x {current} = {result}")
    
    current += 1

print("출력 완료")

# %% [markdown]
# ![그림2.png](data:image/png;base64,...)

# %% [markdown]
# ## 9. 가장 많이 나온 수 중 가장 작은 값을 출력하기
#
# 여러 개의 정수가 공백으로 입력될 때, 각 숫자가 몇 번 나왔는지 계산하여 가장 많이 나온 숫자를 출력하는 프로그램을 작성하시오.
#
# 단, 가장 많이 나온 숫자가 여러 개라면 그 중에서 가장 작은 숫자를 출력하시오.
#
# ### **입력**
# 첫째 줄에 정수의 개수 N이 주어진다.
# 둘째 줄에 N개의 정수가 공백으로 구분되어 주어진다.
#
# ### **출력**
# 가장 많이 나온 숫자를 출력한다.
#
# ### 입력 예제 1
# ```
# 8
# 1 3 2 3 4 3 2 2
# ```
# ### 출력 예제 1
# ```
# 2
# ```

# %%
#########################################################
# 9번 문제 코드 작성하기
########################################################
from collections import Counter

def get_smallest_most_frequent(nums):
    if not nums:
        return None
    
    counts = Counter(nums)

    max_freq = max(counts.values())
    
    most_frequent_nums = [num for num, freq in counts.items() if freq == max_freq]
    
    return min(most_frequent_nums)

# %% [markdown]
# ![그림2.png](data:image/png;base64,...)

# %% [markdown]
# ## 10. 합 구하기
#
# 두 정수 a, b가 주어졌을 때, a부터 b까지의 정수 중에서
# 3의 배수이거나 5의 배수인 수는 제외하고 합을 계산하세요
#
# ### **입력**
# 첫째 줄에 두 정수 a, b (1 ≤ a ≤ b ≤ 10,000)가 주어진다.
#
# ### **출력**
# 조건에 맞는 합을 출력한다.
#
# ### 입력 예제 1
# ```
# 1 20
# ```
# ### 출력 예제 1
# ```
# 112
# ```
#
# ### 입력 예제 2
# ```
# 10 20
# ```
# ### 출력 예제 2
# ```
# 90
# ```

# %%
#########################################################
# 10번 문제 코드 작성하기
########################################################
a, b = map(int, input().split())

total_sum = 0

for i in range(a, b + 1):
    if i % 3 != 0 and i % 5 != 0:
        total_sum += i

print(total_sum)
# Out:
# 90

# %% [markdown]
# ![그림2.png](data:image/png;base64,...)
